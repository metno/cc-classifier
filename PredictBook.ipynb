# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image
from IPython.display import Image

file = '/lustre/storeB/project/metproduction/products/webcams/2019/03/07/12/12_20190307T0900Z.jpg'
Image(filename=file, width=640, height=480)

# %%
import os
from subprocess import check_output
from IPython.core.display import display, HTML

modeldir = '/lustre/storeB/project/metproduction/static_data/camsatrec/models/v41_32_lt2_3000'
epoch=3673
out = check_output(["./predict.py", "--filename", file, '--modeldir', modeldir,'--epoch',"3673",'--with-probs','t'])

display(HTML("<h4>cloud coverage prediction: %s</h4>" % out.decode('utf-8')))
# Out:
# <h4>cloud coverage prediction: 5 probabilities: [ 0.00%, 0.02%, 3.29%, 17.54%, 29.81%, 37.13%, 11.84%, 0.37%, 0.00%,  ] spread: 0.02
# </h4>
